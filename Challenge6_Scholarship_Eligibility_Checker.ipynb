# %% [markdown]
# <a href="https://colab.research.google.com/github/umasankari11/Python-Coding-Challenges/blob/main/Challenge6_Scholarship_Eligibility_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = "Uma"
marks = 98
attendance = 95
family_income = 25000


if marks >= 90 and attendance >= 90:
    scholarship = "Full Scholarship"
elif marks >= 80 or attendance >= 85:
    scholarship = "Half Scholarship"
elif marks >= 70 and family_income < 30000:
    scholarship = "Need-Based Scholarship"
else:
    scholarship = "Not Eligible"


print("Student Name:", student_name)
print("Marks:", marks)
print("Attendance:", attendance)
print("Family Income:", family_income)
print("Scholarship Status:", scholarship)
# Out:
# Student Name: Uma
# Marks: 98
# Attendance: 95
# Family Income: 25000
# Scholarship Status: Full Scholarship
